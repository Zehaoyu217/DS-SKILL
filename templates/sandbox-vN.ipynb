# %% [markdown]
# # Sandbox v{N} — <short title>
#
# **Purpose:** scratch exploration and hypothesis probing for v{N}. This notebook **must only call functions from `ds-workspace/src/`** (Iron Law #10). Class or `fit` definitions inline are a violation.
#
# ## Structure per probe
#
# Each probe below is one logical investigation. Copy the block and fill in.
#
# - **Context:** why this probe right now — which hypothesis / finding / DGP prediction it touches.
# - **COT:** chain of thought — what you expect, what would surprise you, what alternatives.
# - **Code cell:** calls into `src/` only.
# - **Output:** raw metric / plot.
# - **Interpretation:** what the output means — confirm, refute, inconclusive.
# - **Links out:** which `findings/` or `disproven/` card this feeds into, and a `step-journal` entry id.
#
# Never leave a probe without an interpretation and a link out — orphan probes are invisible to `consistency_lint`.

# %% [markdown]
# ## Setup

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parents[0] / 'src'))

# Only import from ds-workspace/src. No class/def in this notebook.
# from data.load import load_train, load_test
# from features.basic import build_features
# from evaluation.cv import cv_score

# %% [markdown]
# ## Probe 1 — <slug>
#
# **Context:** touches H-v{N}-XX, DGP prediction P-NNN.
#
# **COT:**
# - Expectation: ...
# - Would surprise me if: ...
# - Alternatives considered: ...

# %%
# call into src/ only

# %% [markdown]
# **Interpretation:** <confirm | refute | inconclusive> — <one paragraph>.
#
# **Links out:**
# - findings/v{N}-fNNN.md OR disproven/v{N}-dNNN.md
# - step-journal entry v{N}-jNNN

# %% [markdown]
# ## Probe 2 — <slug>
#
# (copy the block above)
